# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Alice in Wonder Land

# %%
text = open('data/Alice.txt').read()
stopwords = set(STOPWORDS)
stopwords.add('said')

# %%
len(STOPWORDS), type(STOPWORDS)
# Out:
# (192, set)

# %%
wc = WordCloud(background_color='white', max_words=2000, stopwords=stopwords)
wc = wc.generate(text)

# %%
type(wc.words_)
# Out:
# dict

# %%
keys = list(wc.words_.keys())
values = list(wc.words_.values())
for i in range(10):
    print(f'{keys[i]}; {values[i]}')
# Out:
# Alice; 1.0
# little; 0.29508196721311475
# one; 0.27595628415300544
# know; 0.2459016393442623
# went; 0.226775956284153
# thing; 0.2185792349726776
# time; 0.2103825136612022
# Queen; 0.20765027322404372
# see; 0.1830601092896175
# King; 0.17486338797814208

# %%
plt.figure(figsize=(12,6))
plt.imshow(wc, interpolation='bilinear')        # , interpolation='bilinear' 생략가능
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# - 배경그림에 표시하기

# %%
mask = np.array(Image.open('data/Alice_mask.png'))

plt.figure(figsize=(8,8))
plt.imshow(mask, cmap=plt.cm.gray, interpolation='bilinear')        # cmap=plt.cm.gray 생략가능
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
wc = WordCloud(background_color='white', max_words=1000, stopwords=stopwords, mask=mask)
wc = wc.generate(text)

# %%
plt.figure(figsize=(8,8))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## Star Wars A New Hope

# %%
with open('data/A_new_hope.txt') as fd:
    text = fd.read()
text = text.replace("HAN",'Han')
text = text.replace("LUKE'S",'Luke')

mask = np.array(Image.open('data/Stormtrooper_mask.png'))

# %%
stopwords = set(STOPWORDS)
stopwords.add('int')
stopwords.add('ext')

# %%
wc = WordCloud(max_words=1000, mask=mask, stopwords=stopwords, margin=10, random_state=1).generate(text)
defaut_colors = wc.to_array()

# %%
import random

def grey_color(word, font_size, position, orientation, random_state=None, **kwargs):
    return 'hsl(0,0%%, %d%%)' % random.randint(60,100)      
    # hue(색), saturation(진하기), lightness(밝기) --> hsl

# %%
plt.figure(figsize=(12,12))
plt.imshow(wc.recolor(color_func=grey_color, random_state=3), interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
keys = list(wc.words_.keys())
values = list(wc.words_.values())
for i in range(10):
    print(f'{keys[i]}; {values[i]}')
# Out:
# Luke; 1.0
# Han; 0.45121951219512196
# DEATH STAR; 0.3902439024390244
# THREEPIO; 0.36585365853658536
# Ben; 0.2665505226480836
# Leia; 0.19686411149825783
# ship; 0.19686411149825783
# Artoo; 0.17247386759581881
# one; 0.1672473867595819
# X WING; 0.16550522648083624
